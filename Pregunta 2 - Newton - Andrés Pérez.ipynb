# %% [markdown]
# Determine todas las raíces del polinomio
#
# x**5−6∗x**4+2∗x**3+20∗x**2−27∗x+10=0
# .

# %%
import numpy as np
from scipy.optimize import newton

def polinomio(x):
    return x**5 - 6*x**4 + 2*x**3 + 20*x**2 - 27*x + 10

def derivada_polinomio(x):
    return 5*x**4 - 24*x**3 + 6*x**2 + 40*x - 27

valores_iniciales = [0, 1, 2, 3, 4, 5]

raices = []
for valor_inicial in valores_iniciales:
    try:
        raiz = newton(polinomio, valor_inicial, fprime=derivada_polinomio)
        raiz = round(raiz, 6)
        if raiz not in raices:
            raices.append(raiz)
    except RuntimeError:
        pass

raices.sort()

print("Las raíces encontradas en orden ascendente son:", raices)
# Out:
# Las raíces encontradas en orden ascendente son: [np.float64(-2.0), np.float64(0.999998), np.float64(1.0), np.float64(1.000003), np.float64(1.000006), np.float64(5.0)]

# %%
import matplotlib.pyplot as plt
import numpy as np

x_vals = np.linspace(min(raices) - 1, max(raices) + 1, 1000)
y_vals = polinomio(x_vals)

plt.figure(figsize=(10, 6))
plt.plot(x_vals, y_vals, label='Polinomio', color='blue')
plt.axhline(0, color='black', linewidth=0.5)

for raiz in raices:
    plt.plot(raiz, 0, 'ro')  # 'ro' para puntos rojos en las raíces
    plt.axvline(raiz, color='red', linestyle='--', linewidth=0.8)
    plt.text(raiz, max(y_vals) * 0.1, f'{raiz:.4f}', fontsize=9, ha='center')

plt.title('Raíces del Polinomio')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
